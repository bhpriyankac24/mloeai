# %% [markdown]
# <a href="https://colab.research.google.com/github/bhpriyankac24/mloeai/blob/main/my1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
a=100
b=20
c=a+b
print("Sum=",c)
# Out:
# Sum= 120
